# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.3.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
palyer <- read.csv("player.csv")

# %%
player_data <- as.data.frame(palyer)

# %%
team <- read.csv("team.csv")

# %%
team <- as.data.frame(team)

# %%
player_data
# Out:
#       X     player_api_id player_name              overall_rating gk_rating
# 1      1    2625          Patryk Rachwal,18        63             153
# 2      2    2752          Diego Mainz              72              53
# 3      3    2768          Jose Dorado              75             128
# 4      4    2770          Ignacio Gonzalez         74             148
# 5      5    2790          Alberto Rey              73             144
# 6      6    2796          Javier Jimenez           69             340
# 7      7    2802          Pablo Hernandez          82             146
# 8      8    2805          Ruben Perez              76             141
# 9      9    2857          Ivan Perez               72             143
# 10    10    2862          Vicente Sanchez          76             146
# 11    11    2907          Gregory Lacombe          NA              NA
# 12    12    2973          Ugur Inceman             72             147
# ...

# %%
team
# Out:
#     X   team_id team_name                    build_play chance_creation
# 1    1  1601    Ruch Chorzów                 139        186
# 2    2  1773    Oud-Heverlee Leuven          153        157
# 3    3  1957    Jagiellonia Bialystok        158        163
# 4    4  2033    S.C. Olhanense               147        165
# 5    5  2182    Lech Poznan                  176        196
# 6    6  2183    P. Warszawa                    0        180
# 7    7  2186    Cracovia                     125        168
# 8    8  4049    Tubize                         0          0
# 9    9  4064    Feirense                       0          0
# 10  10  4087    Évian Thonon Gaillard FC     156        180
# 11  11  4170    US Boulogne Cote D'Opale       0        165
# 12  12  6269    Novara                       179        172
# 13  13  6351    KAS Eupen                      0        160
# 14  14  6367    Uniao da Madeira               0          0
# ...

# %% [markdown]
# # Q1: Which are the top 10 players by overall rating?

# %%
player_data %>%
select(player_name, overall_rating) %>%
arrange (desc(overall_rating)) %>% head(10)
# Out:
#    player_name       overall_rating
# 1  Lionel Messi      94
# 2  Gianluigi Buffon  93
# 3  Wayne Rooney      93
# 4  Cristiano Ronaldo 93
# 5  Xavi Hernandez    92
# 6  Gregory Coupet    92
# 7  Thierry Henry     91
# 8  John Terry        91
# 9  Iker Casillas     91
# 10 Alessandro Nesta  91

# %% [markdown]
# # Q2: Which are the top 10 goalkeepers by sum of gk attributes?

# %%
player_data %>%
select(player_name, gk_rating) %>%
arrange (desc(gk_rating)) %>% head(10)
# Out:
#    player_name       gk_rating
# 1  Gianluigi Buffon  449
# 2  Gregory Coupet    447
# 3  Petr Cech         445
# 4  Iker Casillas     442
# 5  Manuel Neuer      440
# 6  Julio Cesar       438
# 7  Sebastian Frey    437
# 8  Edwin van der Sar 436
# 9  David De Gea      429
# 10 Pepe Reina        428

# %% [markdown]
# # Q3: Which are the top 10 players by number of appearances (with any team they played with)?

# %%
player_data %>%
select(player_name, number_of_appearances) %>%
arrange (desc(number_of_appearances)) %>% head(10)
# Out:
#    player_name          number_of_appearances
# 1  Steve Mandanda       300
# 2  Stephane Ruffier     294
# 3  Gorka Iraizoz Moreno 286
# 4  Samir Handanovic     286
# 5  Hugo Lloris          282
# 6  Tim Howard           282
# 7  Joe Hart             275
# 8  Cedric Carrasso      268
# 9  Daniel Congre        262
# 10 Moussa Sissoko       260

# %% [markdown]
# # Q4: Which are the top 10 teams by sum of build up play attributes?

# %%
team %>%
select(team_name, build_play) %>%
arrange (desc(build_play)) %>% head(10)
# Out:
#    team_name                  build_play
# 1  Torino                     209
# 2  Udinese                    205
# 3  Fortuna Düsseldorf         198
# 4  Podbeskidzie Bielsko-Biala 193
# 5  Korona Kielce              192
# 6  Widzew Lódz                190
# 7  Widzew Lódz                190
# 8  Carpi                      190
# 9  FC Nantes                  189
# 10 Sassuolo                   188

# %% [markdown]
# # Q5: Which are the top 10 teams by sum of chance creation attributes?

# %%
team %>%
select(team_name, chance_creation) %>%
arrange (desc(chance_creation)) %>% head(10)
# Out:
#    team_name           chance_creation
# 1  Lazio               220
# 2  SV Werder Bremen    216
# 3  Napoli              215
# 4  Bayer 04 Leverkusen 210
# 5  Burnley             210
# 6  Cardiff City        210
# 7  Manchester City     210
# 8  Aberdeen            210
# 9  Rangers             210
# 10 Tottenham Hotspur   210

# %% [markdown]
# # Q6: Which are the top 10 teams by sum of defense attributes?

# %%
team %>%
select(team_name, defense_rating) %>%
arrange (desc(defense_rating)) %>% head(10)
# Out:
#    team_name             defense_rating
# 1  Jagiellonia Bialystok 210
# 2  SC Bastia             210
# 3  Zaglebie Lubin        210
# 4  Leicester City        210
# 5  Cardiff City          210
# 6  1. FC Kaiserslautern  210
# 7  Southampton           210
# 8  AS Nancy-Lorraine     210
# 9  Blackpool             210
# 10 Stade Brestois 29     210

# %% [markdown]
# # Q7: Which are the top 10 teams by number of scored goals?

# %%
team %>%
select(team_name, goals_scored) %>%
arrange (desc(goals_scored)) %>% head(10)
# Out:
#    team_name         goals_scored
# 1  FC Barcelona      849
# 2  Real Madrid CF    843
# 3  Celtic            695
# 4  FC Bayern Munich  653
# 5  PSV               652
# 6  Ajax              647
# 7  FC Basel          619
# 8  Manchester City   606
# 9  Chelsea           583
# 10 Manchester United 582
